# %% [markdown]
# #                  ........................    Education Post 12th Data Analysis

# %% [markdown]
# ![Green%20Illustrative%20Organic%20Plant%20Zoom%20Virtual%20Background.png](attachment:Green%20Illustrative%20Organic%20Plant%20Zoom%20Virtual%20Background.png)

# %% [markdown]
# ## Data
# The objective of this analysis is to gain insights into the characteristics of colleges and answer key questions related to the educational landscape. By understanding the data, we aim to inform strategies for improving the quality of education and enhancing the overall college experience. The analysis will provide valuable insights and recommendations for stakeholders in the education sector.

# %% [markdown]
# # Data Description

# %% [markdown]
# * Names: Names of various university and colleges
# * Apps: Number of applications received
# * Accept: Number of applications accepted
# * Enroll: Number of new students enrolled
# * Top10perc: Percentage of new students from top 10% of Higher Secondary class
# * Top25perc: Percentage of new students from top 25% of Higher Secondary class
# * F.Undergrad: Number of full-time undergraduate students
# * P.Undergrad: Number of part-time undergraduate students
# * Outstate: Number of students for whom the particular college or university is Out-of-state tuition
# * Room.Board: Cost of Room and board
# * Books: Estimated book costs for a student
# * Personal: Estimated personal spending for a student
# * PhD: Percentage of faculties with Ph.D.’s
# * Terminal: Percentage of faculties with terminal degree
# * S.F.Ratio: Student/faculty ratio
# * perc.alumni: Percentage of alumni who donate
# * Expend: The Instructional expenditure per student
# * Grad.Rate: Graduation rate

# %% [markdown]
# # Basic Steps

# %%
#1-	Display the top 5 rows.
#2-	Display the last 5 rows
#3-	Check the shape of dataset.
#4-	Check the datatypes of each feature.
#5-	Check the Statistical summary 
#6-	Check the null values
#7-	Check the duplicate values
#8-	Check the anomalies or wrong entries.
#9-	Check the outliers and their authenticity.
#10-	Do the necessary data cleaning steps like dropping duplicates, unnecessary columns, null value imputation, outliers treatment etc.

# %% [markdown]
# # import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Loading dataset

# %%
df=pd.read_excel('1-Education_Post_12th_Standard_New.xlsx')

# %% [markdown]
# # Basic Data Exploration

# %% [markdown]
# ## 1-	Display the top 5 rows.

# %%
df.head()
# Out:
#                           Names    Apps  Accept  Enroll  Top10perc  Top25perc  \
# 0  Abilene Christian University  1660.0    1232   721.0       23.0         52
# 1            Adelphi University  2186.0    1924   512.0       16.0         29
# 2                Adrian College  1428.0    1097   336.0       22.0         50
# 3           Agnes Scott College   417.0     349     NaN       60.0         89
# 4     Alaska Pacific University   193.0     146    55.0       16.0         44
#
#    F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  Personal  PhD  \
# 0         2885          537      7440        3300    450    2200.0   70
# 1         2683         1227     12280        6450    750    1500.0   29
# 2         1036           99     11250        3750    400    1165.0   53
# 3          510           63     12960        5450    450     875.0   92
# 4          249          869      7560        4120    800    1500.0   76
#
#    Terminal S.F.Ratio  perc.alumni  Expend  Grad.Rate
# 0        78      18.1           12    7041         60
# 1        30         ?           16   10527         56
# 2        66      12.9           30    8735         54
# 3        97       7.7           37   19016         59
# 4        72      11.9            2   10922         15

# %% [markdown]
# ## Observation
# *There are non integer values in S.F.Ratio in our dataset.
# *There are NaN(Non null values) in Eroll column.

# %% [markdown]
# ## 2-	Display the last 5 rows

# %%
df.tail()
# Out:
#                               Names     Apps  Accept  Enroll  Top10perc  \
# 772         Worcester State College   2197.0    1515   543.0        4.0
# 773               Xavier University   1959.0    1805   695.0       24.0
# 774  Xavier University of Louisiana   2097.0    1915   695.0       34.0
# 775                 Yale University  10705.0    2453  1317.0       95.0
# 776    York College of Pennsylvania   2989.0    1855   691.0       28.0
#
#      Top25perc  F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  \
# 772         26         3089         2029      6797        3900    500
# 773         47         2849         1107     11520        4960    600
# 774         61         2793          166      6900        4200    617
# 775         99         5217           83     19840        6510    630
# 776         63         2988         1726      4990        3560    500
#
#      Personal  PhD  Terminal S.F.Ratio  perc.alumni  Expend  Grad.Rate
# 772    1200.0   60        60        21           14    4469         40
# 773    1250.0   73        75      13.3           31    9189         83
# 774     781.0   67        75      14.4           20    8323         49
# 775    2115.0   96        96       5.8           49   40386         99
# 776    1250.0   75        75      18.1           28    4509         99

# %% [markdown]
# # Observations:
# * There are no NaN value in our dataset at the bottom in both S.F.Ratio and Enroll.

# %% [markdown]
# ## 3-	Check the shape of dataset.

# %%
df.shape
# Out:
# (777, 18)

# %% [markdown]
# # Observations:
# * The number of columns in our dataset is 777.
# * The number of rows in our dataset is 18.

# %% [markdown]
# ## 4-	Check the datatypes of each feature.

# %%
df.info()
df.dtypes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 777 entries, 0 to 776
# Data columns (total 18 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Names        777 non-null    object
#  1   Apps         775 non-null    float64
#  2   Accept       777 non-null    int64
#  3   Enroll       775 non-null    float64
#  4   Top10perc    773 non-null    float64
#  5   Top25perc    777 non-null    int64
#  6   F.Undergrad  777 non-null    int64
#  7   P.Undergrad  777 non-null    int64
#  8   Outstate     777 non-null    int64
#  9   Room.Board   777 non-null    int64
#  10  Books        777 non-null    int64
#  11  Personal     774 non-null    float64
#  12  PhD          777 non-null    int64
#  13  Terminal     777 non-null    int64
#  14  S.F.Ratio    777 non-null    object
#  15  perc.alumni  777 non-null    int64
#  16  Expend       777 non-null    int64
#  17  Grad.Rate    777 non-null    int64
# dtypes: float64(4), int64(12), object(2)
# memory usage: 109.4+ KB
# Names           object
# Apps           float64
# Accept           int64
# Enroll         float64
# Top10perc      float64
# Top25perc        int64
# F.Undergrad      int64
# P.Undergrad      int64
# Outstate         int64
# Room.Board       int64
# Books            int64
# Personal       float64
# PhD              int64
# Terminal         int64
# S.F.Ratio       object
# perc.alumni      int64
# Expend           int64
# Grad.Rate        int64
# dtype: object

# %% [markdown]
# # Observations:
# * There are Integer , float and object data types in the given dataset.

# %% [markdown]
# ## 5-	Check the Statistical summary

# %%
df.describe()
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    775.000000    777.000000   775.000000  773.000000  777.000000
# mean    3007.592258   2018.804376   780.961290   27.620957   55.796654
# std     3873.414660   2451.113971   930.077779   17.645470   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      778.000000    604.000000   242.500000   15.000000   41.000000
# 50%     1561.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3635.000000   2424.000000   902.500000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   547.875161
# std     4850.420531   1522.431887   4023.016484  1096.696416   167.426237
# min      139.000000      1.000000   2340.000000  1780.000000     0.000000
# 25%      992.000000     95.000000   7320.000000  3597.000000   465.000000
# 50%     1707.000000    353.000000   9990.000000  4200.000000   500.000000
# 75%     4005.000000    967.000000  12925.000000  5050.000000   600.000000
# max    31643.000000  21836.000000  21700.000000  8124.000000  2340.000000
#
#             Personal         PhD    Terminal  perc.alumni        Expend  \
# count     774.000000  777.000000  777.000000   777.000000    777.000000
# mean     1601.507752   72.660232   79.702703    22.743887   9660.171171
# std      7369.594038   16.328155   14.722359    12.391801   5221.768440
# min        50.000000    8.000000   24.000000     0.000000   3186.000000
# 25%       855.000000   62.000000   71.000000    13.000000   6751.000000
# 50%      1200.000000   75.000000   82.000000    21.000000   8377.000000
# 75%      1687.500000   85.000000   92.000000    31.000000  10830.000000
# max    205500.000000  103.000000  100.000000    64.000000  56233.000000
#
#        Grad.Rate
# count  777.00000
# mean    65.46332
# std     17.17771
# min     10.00000
# 25%     53.00000
# 50%     65.00000
# 75%     78.00000
# max    118.00000

# %% [markdown]
# # Obeservations:
# * Describing the data with the given attributes like count, mean, std,min,25%,50%,75%,max.

# %% [markdown]
# ## 6-	Check the null values

# %%
df[df.isnull().sum(axis=1)>0]
# Out:
#                                     Names    Apps  Accept  Enroll  Top10perc  \
# 3                     Agnes Scott College   417.0     349     NaN       60.0
# 9               Alderson-Broaddus College     NaN     498   172.0       21.0
# 41                     Bellarmine College     NaN     707   308.0       39.0
# 81                    Campbell University  2087.0    1339     NaN       20.0
# 102  Central Connecticut State University  4158.0    2532   902.0        NaN
# 103     Central Missouri State University  4681.0    4101  1436.0        NaN
# 128                 College of Notre Dame   344.0     264    97.0        NaN
# 129     College of Notre Dame of Maryland   457.0     356   177.0        NaN
# 166                    Dillard University  1998.0    1376   651.0       41.0
# 175                       Earlham College  1358.0    1006   274.0       35.0
# 177       East Tennessee State University  3330.0    2730  1303.0       15.0
#
#      Top25perc  F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  \
# 3           89          510           63     12960        5450    450
# 9           44          799           78     10468        3380    660
# 41          63         1198          605      8840        2950    750
# 81          54         3191         1204      7550        2790    600
# 102         24         6394         3881      5962        4444    500
# 103         35         8094         1596      4620        3288    300
# 128         42          500          331     12600        5520    630
# 129         61          667         1983     11180        5620    600
# 166         88         1539           45      6700        3650    500
# 175         63         1028           13     15036        4056    600
# 177         36         6706         2640      5800        3000    600
#
#      Personal  PhD  Terminal S.F.Ratio  perc.alumni  Expend  Grad.Rate
# 3       875.0   92        97       7.7           37   19016         59
# 9      1800.0   40        41      11.5           15    8991         52
# 41     1290.0   74        82      13.1           31    6668         84
# 81      500.0   77        77         ?           34    3739         63
# 102     985.0   69        73      16.7            4    4900         49
# 103    2250.0   69        80      19.7            4    5501         50
# 128    2250.0   77        80      10.4            7    9773         43
# 129     700.0   64        64      11.5           32    7477         75
# 166       NaN   52        52      14.1           12    7566         61
# 175       NaN   90        94      10.6           46   14634         78
# 177       NaN   73        75        14            9    9825         42

# %% [markdown]
# ## Observation
# *There is NaN values in Apps and Enroll.

# %% [markdown]
# ## 7-	Check the duplicate values

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df[df.duplicated()==True]
# Out:
# Empty DataFrame
# Columns: [Names, Apps, Accept, Enroll, Top10perc, Top25perc, F.Undergrad, P.Undergrad, Outstate, Room.Board, Books, Personal, PhD, Terminal, S.F.Ratio, perc.alumni, Expend, Grad.Rate]
# Index: []

# %% [markdown]
# # Obersevation
# * No duplicated values in our dataset.

# %% [markdown]
# ## 8- Check the anomalies or wrong entries

# %%
df[df['S.F.Ratio']=='?']
# Out:
#                      Names    Apps  Accept  Enroll  Top10perc  Top25perc  \
# 1       Adelphi University  2186.0    1924   512.0       16.0         29
# 81     Campbell University  2087.0    1339     NaN       20.0         54
# 241  Gwynedd Mercy College   380.0     237   104.0       30.0         56
#
#      F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  Personal  PhD  \
# 1           2683         1227     12280        6450    750    1500.0   29
# 81          3191         1204      7550        2790    600     500.0   77
# 241          716         1108     11000        5550    500     500.0   36
#
#      Terminal S.F.Ratio  perc.alumni  Expend  Grad.Rate
# 1          30         ?           16   10527         56
# 81         77         ?           34    3739         63
# 241        41         ?           22    7483         96

# %% [markdown]
# ## Observation
# * Shows that in S.F.Ratio row no:1,81 and 241 contains '?'(Non integer value).

# %% [markdown]
# ## 9-	Check the outliers and their authenticity.

# %%
plt.figure(figsize=(10,10))
sns.boxplot(data=df,orient='h')
# Out:
# <Axes: >

# %%
def remove_outlier(col):
    sorted(col)
    Q1,Q3=col.quantile([0.25,0.75])
    IQR=Q3-Q1
    lower_range= Q1-(1.5 * IQR)
    upper_range= Q3+(1.5 * IQR)
    return lower_range, upper_range    

for i in df.columns:
    if df[i].dtype !='object':
        lr,ur=remove_outlier(df[i])
        df[i]=np.where(df[i]>ur,ur,df[i])
        df[i]=np.where(df[i]<lr,lr,df[i])

# %% [markdown]
# ## Observation
# *Shows the outliners in Expend and  F.Undergrad.

# %% [markdown]
# ## 10-	Do the necessary data cleaning steps like dropping duplicates, unnecessary columns, null value imputation, outliers treatment etc.

# %%
df['S.F.Ratio']=df['S.F.Ratio'].replace('?',np.nan)

# %%
df.head()
# Out:
#                           Names    Apps  Accept  Enroll  Top10perc  Top25perc  \
# 0  Abilene Christian University  1660.0  1232.0   721.0       23.0       52.0
# 1            Adelphi University  2186.0  1924.0   512.0       16.0       29.0
# 2                Adrian College  1428.0  1097.0   336.0       22.0       50.0
# 3           Agnes Scott College   417.0   349.0     NaN       60.0       89.0
# 4     Alaska Pacific University   193.0   146.0    55.0       16.0       44.0
#
#    F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  Personal   PhD  \
# 0       2885.0        537.0    7440.0      3300.0  450.0    2200.0  70.0
# 1       2683.0       1227.0   12280.0      6450.0  750.0    1500.0  29.0
# 2       1036.0         99.0   11250.0      3750.0  400.0    1165.0  53.0
# 3        510.0         63.0   12960.0      5450.0  450.0     875.0  92.0
# 4        249.0        869.0    7560.0      4120.0  800.0    1500.0  76.0
#
#    Terminal  S.F.Ratio  perc.alumni   Expend  Grad.Rate
# 0      78.0       18.1         12.0   7041.0       60.0
# 1      39.5        NaN         16.0  10527.0       56.0
# 2      66.0       12.9         30.0   8735.0       54.0
# 3      97.0        7.7         37.0  16948.5       59.0
# 4      72.0       11.9          2.0  10922.0       15.5

# %%
df.isnull().sum()
# Out:
# Names          0
# Apps           2
# Accept         0
# Enroll         2
# Top10perc      4
# Top25perc      0
# F.Undergrad    0
# P.Undergrad    0
# Outstate       0
# Room.Board     0
# Books          0
# Personal       3
# PhD            0
# Terminal       0
# S.F.Ratio      3
# perc.alumni    0
# Expend         0
# Grad.Rate      0
# dtype: int64

# %%
for i in ["Outstate","Expend","F.Undergrad","Apps","Room.Board"]:
    plt.figure(figsize=(10,3))
    df.boxplot(column=i)
    plt.show()

# %% [markdown]
# ## Observation
# * Exchanged values with NaN.

# %% [markdown]
# ## 1.	Application and Enrollment Analysis
# *	What is the average number of applications received by colleges?
# *	What percentage of applications are accepted on average across all colleges?
# *	What is the average enrollment rate (number of students enrolled divided by number of applications accepted)?
# *	Which college has the highest number of applications received?

# %%
#1What is the average number of applications received by colleges?
average_applications = df['Apps'].mean()
print(f"Average number of applications received by colleges: {average_applications}")
# Out:
# Average number of applications received by colleges: 3007.592258064516

# %%
#What percentage of applications are accepted on average across all colleges?
df['Accept'] = df['Accept'] / df['Apps'] * 100
average_acceptance_rate = df['Accept'].mean()
print(f"Average percentage of applications accepted across all colleges: {average_acceptance_rate}%")
# Out:
# Average percentage of applications accepted across all colleges: 74.66207408888458%

# %%
#What is the average enrollment rate (number of students enrolled divided by number of applications accepted)?
df['Enroll'] = df['Enroll'] / df['Accept'] * 100
average_enrollment_rate = df['Enroll'].mean()
print(f"Average enrollment rate: {average_enrollment_rate}%")
# Out:
# Average enrollment rate: 1165.6270717382552%

# %%
#Which college has the highest number of applications received?
college_max_applications = df.loc[df['Apps'].idxmax(), 'Names']
print(f"College with the highest number of applications received: {college_max_applications}")
# Out:
# College with the highest number of applications received: Rutgers at New Brunswick

# %% [markdown]
# ## 2.	Academic Excellence
# *	What is the average percentage of new students from the top 10% of their higher secondary class across all colleges?
# *	What is the average percentage of new students from the top 25% of their higher secondary class?
# *	Is there a correlation between the percentage of students from the top 10% and the top 25% of their higher secondary class?

# %%
#What is the average percentage of new students from the top 10% of their higher secondary class across all colleges?
average_top_10_percent = df['Top10perc'].mean()
print(f"Average percentage of new students from the top 10% of their higher secondary class: {average_top_10_percent}%")
# Out:
# Average percentage of new students from the top 10% of their higher secondary class: 27.620957309184995%

# %%
#What is the average percentage of new students from the top 25% of their higher secondary class?
average_top_25_percent = df['Top25perc'].mean()
print(f"Average percentage of new students from the top 25% of their higher secondary class: {average_top_25_percent}%")
# Out:
# Average percentage of new students from the top 25% of their higher secondary class: 55.7966537966538%

# %%
#Is there a correlation between the percentage of students from the top 10% and the top 25% of their higher secondary class?
correlation = df['Top10perc'].corr(df['Top25perc'])
print(f"Correlation between the percentage of students from the top 10% and the top 25% of their higher secondary class: {correlation}")
# Out:
# Correlation between the percentage of students from the top 10% and the top 25% of their higher secondary class: 0.8916010734346559

# %% [markdown]
# ## 3.	Student Demographics
# *	What is the average number of full-time undergraduate students per college?
# *	What is the average number of part-time undergraduate students per college?
# *	Which college has the highest number of out-of-state students?

# %%
#What is the average number of full-time undergraduate students per college?
average_full_time_students = df['F.Undergrad'].mean()
print(f"Average number of full-time undergraduate students per college: {average_full_time_students}")
# Out:
# Average number of full-time undergraduate students per college: 3699.907335907336

# %%
#What is the average number of part-time undergraduate students per college?
average_part_time_students = df['P.Undergrad'].mean()
print(f"Average number of part-time undergraduate students per college: {average_part_time_students}")
# Out:
# Average number of part-time undergraduate students per college: 855.2985842985843

# %%
#Which college has the highest number of out-of-state students?
college_max_out_of_state = df.loc[df['Outstate'].idxmax(), 'Names']
print(f"College with the highest number of out-of-state students: {college_max_out_of_state}")
# Out:
# College with the highest number of out-of-state students: Bennington College

# %% [markdown]
# ## 4.	Cost and Spending
# *	What is the average cost of room and board across all colleges?
# *	What is the average estimated book cost for a student?
# *	What is the average estimated personal spending for a student?
# *	How does the instructional expenditure per student vary across colleges?

# %%
#What is the average cost of room and board across all colleges?
average_room_and_board = df['Room.Board'].mean()
print(f"Average cost of room and board across all colleges: ${average_room_and_board}")
# Out:
# Average cost of room and board across all colleges: $4357.526383526383

# %%
#What is the average estimated book cost for a student?
average_book_cost = df['Books'].mean()
print(f"Average estimated book cost for a student: ${average_book_cost}")
# Out:
# Average estimated book cost for a student: $547.8751608751609

# %%
#What is the average estimated personal spending for a student?
average_personal_spending = df['Personal'].mean()
print(f"Average estimated personal spending for a student: ${average_personal_spending}")
# Out:
# Average estimated personal spending for a student: $1601.5077519379845

# %%
#How does the instructional expenditure per student vary across colleges?
instructional_expenditure_variation = df[['Names', 'Personal']]
print("Instructional expenditure per student across colleges:")
print(instructional_expenditure_variation)
# Out:
# Instructional expenditure per student across colleges:
#                               Names  Personal
# 0      Abilene Christian University    2200.0
# 1                Adelphi University    1500.0
# 2                    Adrian College    1165.0
# 3               Agnes Scott College     875.0
# 4         Alaska Pacific University    1500.0
# ..                              ...       ...
# 772         Worcester State College    1200.0
# 773               Xavier University    1250.0
# 774  Xavier University of Louisiana     781.0
# 775                 Yale University    2115.0
# 776    York College of Pennsylvania    1250.0
#
# [777 rows x 2 columns]

# %% [markdown]
# ## 5.	Faculty Qualifications
# *	What is the average percentage of faculties with Ph.D.s across all colleges?
# *	What is the average percentage of faculties with terminal degrees?
# *	Is there a correlation between the percentage of faculties with Ph.D.s and the graduation rate?

# %%
#What is the average percentage of faculties with Ph.D.s across all colleges?
avg_phd_percentage = df['PhD'].mean()

print(f"The average percentage of faculties with Ph.D.s across all colleges is: {avg_phd_percentage:.2f}%")
# Out:
# The average percentage of faculties with Ph.D.s across all colleges is: 72.66%

# %%
#What is the average percentage of faculties with terminal degrees?
avg_terminal_percentage = df['Terminal'].mean()

print(f"The average percentage of faculties with terminal degrees across all colleges is: {avg_terminal_percentage:.2f}%")
# Out:
# The average percentage of faculties with terminal degrees across all colleges is: 79.70%

# %%
#Is there a correlation between the percentage of faculties with Ph.D.s and the graduation rate?
correlation = df['PhD'].corr(df['Grad.Rate'])

print(f"The correlation between the percentage of faculties with Ph.D.s and graduation rate is: {correlation:.2f}")
# Out:
# The correlation between the percentage of faculties with Ph.D.s and graduation rate is: 0.31

# %% [markdown]
# ## 6.	Student-Faculty Interaction
# *	What is the average student/faculty ratio across all colleges?
# *	Which college has the lowest student/faculty ratio?
# *	Is there a correlation between the student/faculty ratio and the graduation rate?

# %%
#What is the average student/faculty ratio across all colleges?
df['S.F.Ratio'] = df['Enroll'] / df['PhD']
avg_ratio = df['S.F.Ratio'].mean()

print(f"The average student/faculty ratio across all colleges is: {avg_ratio:.2f}")
# Out:
# The average student/faculty ratio across all colleges is: 10.34

# %%
#Which college has the lowest student/faculty ratio?
df['S.F.Ratio'] = df['Enroll'] / df['PhD']

lowest_ratio_index = df['S.F.Ratio'].idxmin()
lowest_ratio_college = df.loc[lowest_ratio_index,'Names']

print(f"The college with the lowest student/faculty ratio is: {lowest_ratio_college}")
# Out:
# The college with the lowest student/faculty ratio is: Christendom College

# %%
#Is there a correlation between the student/faculty ratio and the graduation rate?
correlation = df['S.F.Ratio'].corr(df['Grad.Rate'])

print(f"The correlation between student/faculty ratio and graduation rate is: {correlation:.2f}")
# Out:
# The correlation between student/faculty ratio and graduation rate is: -0.07

# %% [markdown]
# ## 7.	Alumni Engagement
# *	What is the average percentage of alumni who donate across all colleges?
# *	Is there a correlation between the percentage of alumni who donate and the graduation rate?

# %%
#What is the average percentage of alumni who donate across all colleges?
average_donation_percentage = df['perc.alumni'].mean()
print(f"Average donation percentage across all colleges: {average_donation_percentage:.2f}%")
# Out:
# Average donation percentage across all colleges: 22.74%

# %%
#Is there a correlation between the percentage of alumni who donate and the graduation rate?

correlation = df['perc.alumni'].corr(df['Grad.Rate'])

print(f"Correlation between donation percentage and graduation rate: {correlation:.2f}")

plt.figure(figsize=(8, 6))
sns.scatterplot(x='perc.alumni', y='Grad.Rate', data=df, s=100, color='b', alpha=0.7)
plt.title('perc.alumni vs Grad.Rate')
plt.xlabel('perc.alumni')
plt.ylabel('Grad.Rate')
plt.grid(True)
plt.show()
# Out:
# Correlation between donation percentage and graduation rate: 0.49

# %% [markdown]
# ## 8.	Graduation Rates
# *	What is the average graduation rate across all colleges?
# *	Which college has the highest graduation rate?
# *	Is there a correlation between the instructional expenditure per student and the graduation rate?

# %%
#What is the average graduation rate across all colleges?
average_graduation_rate = df['Grad.Rate'].mean()
print(f"Average graduation rate across all colleges: {average_graduation_rate:.2f}%")
# Out:
# Average graduation rate across all colleges: 65.46%

# %%
#Which college has the highest graduation rate?
highest_graduation_rate_college = df.loc[df['Grad.Rate'].idxmax(), 'Names']
highest_graduation_rate = df['Grad.Rate'].max()

print(f"College with the highest graduation rate: {highest_graduation_rate_college} ({highest_graduation_rate}%)")
# Out:
# College with the highest graduation rate: Cazenovia College (118%)

# %%
#Is there a correlation between the instructional expenditure per student and the graduation rate?

# Calculate correlation coefficient
correlation = df['Expend'].corr(df['Grad.Rate'])
print(f"Correlation between instructional expenditure per student and graduation rate: {correlation:.2f}")

# Visualize the correlation
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Expend', y='Grad.Rate', data=df, s=100, color='b', alpha=0.7)
plt.title('Expend vs Grad.Rate')
plt.xlabel('Expend ($)')
plt.ylabel('Grad.Rate (%)')
plt.grid(True)
plt.show()
# Out:
# Correlation between instructional expenditure per student and graduation rate: 0.39

# %% [markdown]
# ## 9.	Overall Insights
# *	Which factors (applications, acceptance rate, enrollment, academic excellence, costs, faculty qualifications, student/faculty ratio, alumni donations, expenditures) are most strongly associated with higher graduation rates?
# *	What recommendations can be made to colleges to improve their graduation rates based on the data analysis?

# %%
#Which factors (applications, acceptance rate, enrollment, academic excellence, costs, faculty qualifications, student/faculty ratio, alumni donations, expenditures) are most strongly associated with higher graduation rates?
df.head()
df = df.dropna()

# Convert columns to appropriate data types if needed
df['Enroll'] = pd.to_numeric(df['Enroll'], errors='coerce')
df['S.F.Ratio'] = pd.to_numeric(df['S.F.Ratio'],errors='coerce')
# Check the structure of the DataFrame
print(df.info())

# Select relevant columns for correlation analysis
relevant_columns = ['Apps', 'Accept', 'Enroll', 'S.F.Ratio',  'Top10perc', 
                    'Room.Board', 'PhD','perc.alumni', 'Expend', 'Grad.Rate']

# Compute the correlation matrix
correlation_matrix = df[relevant_columns].corr()

# Display correlation matrix
print(correlation_matrix)

# Identify factors most strongly correlated with Graduation Rate
correlation_with_grad_rate = correlation_matrix['Grad.Rate'].sort_values(ascending=False)
print(correlation_with_grad_rate)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 764 entries, 0 to 776
# Data columns (total 18 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Names        764 non-null    object
#  1   Apps         764 non-null    float64
#  2   Accept       764 non-null    int64
#  3   Enroll       764 non-null    float64
#  4   Top10perc    764 non-null    float64
#  5   Top25perc    764 non-null    int64
#  6   F.Undergrad  764 non-null    int64
#  7   P.Undergrad  764 non-null    int64
#  8   Outstate     764 non-null    int64
#  9   Room.Board   764 non-null    int64
#  10  Books        764 non-null    int64
#  11  Personal     764 non-null    float64
#  12  PhD          764 non-null    int64
#  13  Terminal     764 non-null    int64
#  14  S.F.Ratio    764 non-null    float64
#  15  perc.alumni  764 non-null    int64
#  16  Expend       764 non-null    int64
#  17  Grad.Rate    764 non-null    int64
# dtypes: float64(5), int64(12), object(1)
# memory usage: 113.4+ KB
# None
#                  Apps    Accept    Enroll  S.F.Ratio  Top10perc  Room.Board  \
# Apps         1.000000  0.943363  0.846368   0.090700   0.344302    0.169436
# Accept       0.943363  1.000000  0.911336   0.171654   0.197501    0.095105
# Enroll       0.846368  0.911336  1.000000   0.233052   0.185971   -0.036486
# S.F.Ratio    0.090700  0.171654  0.233052   1.000000  -0.383485   -0.358022
# Top10perc    0.344302  0.197501  0.185971  -0.383485   1.000000    0.375651
# Room.Board   0.169436  0.095105 -0.036486  -0.358022   0.375651    1.000000
# PhD          0.393806  0.359035  0.333713  -0.138108   0.537429    0.343354
# perc.alumni -0.088466 -0.158103 -0.179209  -0.406118   0.451758    0.277001
# Expend       0.262631  0.127074  0.066373  -0.583576   0.661679    0.503798
# Grad.Rate    0.150009  0.070710 -0.019744  -0.307118   0.494489    0.430285
#
#                   PhD  perc.alumni    Expend  Grad.Rate
# Apps         0.393806    -0.088466  0.262631   0.150009
# Accept       0.359035    -0.158103  0.127074   0.070710
# Enroll       0.333713    -0.179209  0.066373  -0.019744
# S.F.Ratio   -0.138108    -0.406118 -0.583576  -0.307118
# Top10perc    0.537429     0.451758  0.661679   0.494489
# Room.Board   0.343354     0.277001  0.503798   0.430285
# PhD          1.000000     0.245065  0.434793   0.312200
# perc.alumni  0.245065     1.000000  0.417524   0.488046
# Expend       0.434793     0.417524  1.000000   0.394980
# Grad.Rate    0.312200     0.488046  0.394980   1.000000
# Grad.Rate      1.000000
# Top10perc      0.494489
# perc.alumni    0.488046
# Room.Board     0.430285
# Expend         0.394980
# PhD            0.312200
# Apps           0.150009
# Accept         0.070710
# Enroll        -0.019744
# S.F.Ratio     -0.307118
# Name: Grad.Rate, dtype: float64

# %% [markdown]
# ## What recommendations can be made to colleges to improve their graduation rates based on the data analysis?
# *Recommendations for Colleges
# *Based on the correlation analysis and domain knowledge, make recommendations to colleges to potentially improve their graduation rates:
#
# *Focus on Factors with Positive Correlation: Prioritize factors that have a strong positive correlation with graduation rates, such as improving academic excellence metrics, enhancing faculty qualifications, optimizing student/faculty ratios, and increasing alumni donations.
#
# *Address Factors with Negative Correlation: Identify factors negatively correlated with graduation rates (if any) and develop strategies to mitigate their impact, such as reducing costs without compromising educational quality or improving acceptance rates while maintaining academic standards.
#
# *Data-Driven Decision Making: Encourage colleges to regularly analyze their data and adapt strategies based on ongoing trends and correlations observed in their specific context.
